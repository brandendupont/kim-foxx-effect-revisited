# %% [markdown]
# # Kim Foxx Effect Revisited

# %% [markdown]
# Kim Foxx's office's unprecedented release of 6 years of case-level data provided the opportunity
# for the Marshall Project to investigate the effect of Foxx's policy. In a discussion of data and
# methods the author, Matt Daniels, finishes with a nod to the limitations of his approach: “The aim of this project
# was not to find an absolute figure for a progressive prosecutor’s impact, but rather a rough
# estimate of how  Foxx’s policies affect the people of Cook County.”
#
# The purpose of this study is to provide a precise estimate on the effect of progressive
# prosecutorial policies under Kim Foxx in Cook County, Illinois. Currently, it is the only county in
# the United States that has publicly released case-level data at the intake stage, i.e. when county
# prosecutors decide how aggressively to pursue charges.
#
# We employ two versions of a Bayesian structural time-series (BSTS) developed by (Brodersen et al., 2015) to estimate the number of cases Foxx’s office turned away that would have
# been pursued by previous State’s Attorney Anita Alvarez. We model the first as a single time series w/o controls. In the second, we add time series covariated to improve the model.
#
#
# 1. Model an interrupted time series w/o control, single-pre/post design using a BSTS
#     1. Overall felony cases
#     2. Overall felony retail theft
#     3. Overall felony gun cases
#     4. Overall misdemeanor retail theft
#     5. Overall felony retail theft
#
# The BSTS model recommends adding time-series corvariates that are predictive to our outcome of interest (number of charges issued), but not affected by the intervention that took place (Kim Foxx's decision to decline or lessen charges) when training the model. We add the covariates, weather, holidays, and reported incidents. {cite Campedelli}. **will need to add a longer discussion on controls**
#
# 2. Model an interrupted time series synthethic control using Python port of Causal Impact
#
#     Covariates
#     1. reported incidents of retail thefts
#     2. temperature
#     3. holidays
#
#
# We will explore threats to validity,
# hypothesis tests, and various model diagnostics to provide a sense of confidence around our
# findings.
#
# Datasets

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
from causalimpact import CausalImpact
import matplotlib
import seaborn as sns
import requests as r
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# %matplotlib inline
# add some basic matplotlib defaults
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = (15, 6)
# set plot size and type to ggplot
plt.rcParams['figure.figsize']=(20,10)
plt.style.use('ggplot')

# %% [markdown]
# ### Import Data
#
# Get charge initatiations data from the Circuit. An overview of the data source can be found [here](https://charges.thecircuit.cc/en/methodology/).

# %%
# fetch theft data
cc = r.get('https://charges.thecircuit.cc/page-data/en/theft/page-data.json').json()

# %%
# select data results
cc['result']['data']['Courts']['analysis_charge_counts_by_month_stacked']

# %% [markdown]
# Convert returned json to DataFrame

# %%
theft = pd.DataFrame(cc['result']['data']['Courts']['analysis_charge_counts_by_month_stacked'])

# %% [markdown]
# Add offense type and remove number prefix

# %%
theft['offense_type'] = theft['ucr'].map(lambda x: list(dict(x).values())[0]).str.replace('\d+', '').str.replace("-", " ").str.strip()
# Out:
# <ipython-input-151-3c6e3b1998a2>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   theft['offense_type'] = theft['ucr'].map(lambda x: list(dict(x).values())[0]).str.replace('\d+', '').str.replace("-", " ").str.strip()

# %% [markdown]
# Convert data from unix to readable date.

# %%
theft['case_date'] = pd.to_datetime(theft['case_date'],unit='s')

# %% [markdown]
# Add Felony & Misdemeanor total

# %%
theft['charges_fm'] = theft['charges_f'] + theft['charges_m']

# %% [markdown]
# ### Save Data Locally

# %%
theft.to_csv(r'C:\Users\brand\OneDrive\Documents\grad-school\pui\kim-fox-effect-revisited\data\theft_data_the_circuit_2000-2018.csv')

# %% [markdown]
# ### Subset data for analysis
#
# We will only include retail theft and the Kim Fox Effect timeline

# %%
rt = theft[(theft['offense_type'] == 'retail theft') & (theft['case_date'].dt.year >= 2012)]

# %% [markdown]
# Subset to Only Include KFE Time Frame

# %% [markdown]
# ### Monthly Trends by Felony & Misdemeanor, Felony only, and Misdemeanor only

# %%
for charge_lvl in ['charges_fm', 'charges_f','charges_m']:
    rt.set_index('case_date')[charge_lvl].plot()

# %% [markdown]
# ### Year Retail Theft Trends by Felony & Misdemeanor, Felony only, and Misdemeanor only

# %%
for charge_lvl in ['charges_fm', 'charges_f','charges_m']:  
    rt.groupby(rt['case_date'].dt.year)[charge_lvl].sum().plot(legend=True)

# %%
rt
# Out:
#       case_date  charges_f  charges_m                                 ucr  \
# 841  2014-01-01      306.0        485  {'charge_slug': '54-retail-theft'}
# 845  2014-02-01      206.0        385  {'charge_slug': '54-retail-theft'}
# 851  2014-03-01      269.0        423  {'charge_slug': '54-retail-theft'}
# 859  2014-04-01      290.0        481  {'charge_slug': '54-retail-theft'}
# 863  2014-05-01      274.0        503  {'charge_slug': '54-retail-theft'}
# 867  2014-06-01      289.0        520  {'charge_slug': '54-retail-theft'}
# 873  2014-07-01      257.0        587  {'charge_slug': '54-retail-theft'}
# 879  2014-08-01      262.0        555  {'charge_slug': '54-retail-theft'}
# 880  2014-09-01      276.0        610  {'charge_slug': '54-retail-theft'}
# 887  2014-10-01      282.0        523  {'charge_slug': '54-retail-theft'}
# 893  2014-11-01      256.0        456  {'charge_slug': '54-retail-theft'}
# 897  2014-12-01      282.0        630  {'charge_slug': '54-retail-theft'}
# 902  2015-01-01      282.0        576  {'charge_slug': '54-retail-theft'}
# 906  2015-02-01      272.0        363  {'charge_slug': '54-retail-theft'}
# 911  2015-03-01      253.0        493  {'charge_slug': '54-retail-theft'}
# 917  2015-04-01      255.0        456  {'charge_slug': '54-retail-theft'}
# 920  2015-05-01      223.0        427  {'charge_slug': '54-retail-theft'}
# 928  2015-06-01      237.0        531  {'charge_slug': '54-retail-theft'}
# 934  2015-07-01      258.0        538  {'charge_slug': '54-retail-theft'}
# 935  2015-08-01      258.0        499  {'charge_slug': '54-retail-theft'}
# 943  2015-09-01      268.0        448  {'charge_slug': '54-retail-theft'}
# 948  2015-10-01      247.0        570  {'charge_slug': '54-retail-theft'}
# 954  2015-11-01      227.0        469  {'charge_slug': '54-retail-theft'}
# 956  2015-12-01      284.0        635  {'charge_slug': '54-retail-theft'}
# 961  2016-01-01      236.0        524  {'charge_slug': '54-retail-theft'}
# 968  2016-02-01      256.0        506  {'charge_slug': '54-retail-theft'}
# 974  2016-03-01      229.0        547  {'charge_slug': '54-retail-theft'}
# 975  2016-04-01      227.0        516  {'charge_slug': '54-retail-theft'}
# 980  2016-05-01      258.0        539  {'charge_slug': '54-retail-theft'}
# 987  2016-06-01      262.0        585  {'charge_slug': '54-retail-theft'}
# 992  2016-07-01      219.0        414  {'charge_slug': '54-retail-theft'}
# 997  2016-08-01      219.0        561  {'charge_slug': '54-retail-theft'}
# 1000 2016-09-01      220.0        508  {'charge_slug': '54-retail-theft'}
# 1005 2016-10-01      220.0        523  {'charge_slug': '54-retail-theft'}
# 1012 2016-11-01      200.0        575  {'charge_slug': '54-retail-theft'}
# 1015 2016-12-01      172.0        719  {'charge_slug': '54-retail-theft'}
# 1020 2017-01-01       77.0        689  {'charge_slug': '54-retail-theft'}
# 1027 2017-02-01       97.0        526  {'charge_slug': '54-retail-theft'}
# 1034 2017-03-01       78.0        631  {'charge_slug': '54-retail-theft'}
# 1038 2017-04-01       78.0        585  {'charge_slug': '54-retail-theft'}
# 1042 2017-05-01       66.0        672  {'charge_slug': '54-retail-theft'}
# 1047 2017-06-01       56.0        686  {'charge_slug': '54-retail-theft'}
# 1052 2017-07-01       80.0        640  {'charge_slug': '54-retail-theft'}
# 1058 2017-08-01       62.0        725  {'charge_slug': '54-retail-theft'}
# 1062 2017-09-01       62.0        667  {'charge_slug': '54-retail-theft'}
# 1066 2017-10-01       51.0        617  {'charge_slug': '54-retail-theft'}
# 1071 2017-11-01       60.0        659  {'charge_slug': '54-retail-theft'}
# 1079 2017-12-01       58.0        649  {'charge_slug': '54-retail-theft'}
# 1084 2018-01-01       83.0        759  {'charge_slug': '54-retail-theft'}
# 1088 2018-02-01       60.0        593  {'charge_slug': '54-retail-theft'}
# 1093 2018-03-01       80.0        669  {'charge_slug': '54-retail-theft'}
# 1099 2018-04-01       90.0        616  {'charge_slug': '54-retail-theft'}
# 1100 2018-05-01       75.0        668  {'charge_slug': '54-retail-theft'}
# 1108 2018-06-01       72.0        622  {'charge_slug': '54-retail-theft'}
# 1110 2018-07-01       49.0        655  {'charge_slug': '54-retail-theft'}
# 1119 2018-08-01       87.0        652  {'charge_slug': '54-retail-theft'}
# 1121 2018-09-01       62.0        591  {'charge_slug': '54-retail-theft'}
# 1127 2018-10-01       76.0        693  {'charge_slug': '54-retail-theft'}
# 1132 2018-11-01       60.0        553  {'charge_slug': '54-retail-theft'}
# 1136 2018-12-01       69.0        430  {'charge_slug': '54-retail-theft'}
#
#       offense_type  charges_fm
# 841   retail theft       791.0
# 845   retail theft       591.0
# 851   retail theft       692.0
# 859   retail theft       771.0
# 863   retail theft       777.0
# 867   retail theft       809.0
# 873   retail theft       844.0
# 879   retail theft       817.0
# 880   retail theft       886.0
# 887   retail theft       805.0
# 893   retail theft       712.0
# 897   retail theft       912.0
# 902   retail theft       858.0
# 906   retail theft       635.0
# 911   retail theft       746.0
# 917   retail theft       711.0
# 920   retail theft       650.0
# 928   retail theft       768.0
# 934   retail theft       796.0
# 935   retail theft       757.0
# 943   retail theft       716.0
# 948   retail theft       817.0
# 954   retail theft       696.0
# 956   retail theft       919.0
# 961   retail theft       760.0
# 968   retail theft       762.0
# 974   retail theft       776.0
# 975   retail theft       743.0
# 980   retail theft       797.0
# 987   retail theft       847.0
# 992   retail theft       633.0
# 997   retail theft       780.0
# 1000  retail theft       728.0
# 1005  retail theft       743.0
# 1012  retail theft       775.0
# 1015  retail theft       891.0
# 1020  retail theft       766.0
# 1027  retail theft       623.0
# 1034  retail theft       709.0
# 1038  retail theft       663.0
# 1042  retail theft       738.0
# 1047  retail theft       742.0
# 1052  retail theft       720.0
# 1058  retail theft       787.0
# 1062  retail theft       729.0
# 1066  retail theft       668.0
# 1071  retail theft       719.0
# 1079  retail theft       707.0
# 1084  retail theft       842.0
# 1088  retail theft       653.0
# 1093  retail theft       749.0
# 1099  retail theft       706.0
# 1100  retail theft       743.0
# 1108  retail theft       694.0
# 1110  retail theft       704.0
# 1119  retail theft       739.0
# 1121  retail theft       653.0
# 1127  retail theft       769.0
# 1132  retail theft       613.0
# 1136  retail theft       499.0

# %%
cim = rt[['case_date','charges_f' ]].set_index('case_date')

# %%
cim.index.max()
# Out:
# Timestamp('2018-12-01 00:00:00')

# %%
result = seasonal_decompose(cim[:'2016-11-01'])

# %%
result.plot()

# %% [markdown]
# # Run Causal Impact on Felony Thefts
#
# Review original Kim Foxx Effect methods [here](https://projects.chicagoreporter.com/kim-foxx-prosecutions-20191024/#method).

# %%
pre_period = ['2014-01-01', '2016-11-01']
post_period = ['2016-12-01', '2018-12-01']

figsize = (20, 6)
ci = CausalImpact(cim, pre_period, post_period, model_args={'nseasons': 12, 'prior_level_sd':.1})
# Out:
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:5 out of the last 5 calls to <function fit_model.<locals>._run_vi at 0x00000206724AB790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
ci.plot(figsize=(15, 12))

# %% [markdown]
# ## Review Summary Findings

# %%
print(ci.summary())
# Out:
# Posterior Inference {Causal Impact}
#                           Average            Cumulative
# Actual                    74.4               1860.0
# Prediction (s.d.)         239.83 (11.58)     5995.7 (289.55)
# 95% CI                    [217.72, 263.12]   [5442.97, 6577.98]
#
# Absolute effect (s.d.)    -165.43 (11.58)    -4135.7 (289.55)
# 95% CI                    [-188.72, -143.32] [-4717.98, -3582.97]
#
# Relative effect (s.d.)    -68.98% (4.83%)    -68.98% (4.83%)
# 95% CI                    [-78.69%, -59.76%] [-78.69%, -59.76%]
#
# Posterior tail-area probability p: 0.0
# Posterior prob. of a causal effect: 100.0%
#
# For more details run the command: print(impact.summary('report'))

# %% [markdown]
# ### Review Model Output

# %%
ci.inferences.sample(5)
# Out:
#             complete_preds_means  complete_preds_lower  complete_preds_upper  \
# 2017-03-01            231.286179            165.498392            296.508292
# 2018-02-01            249.537109            167.281477            338.911945
# 2016-02-01            251.898376            189.927796            319.816945
# 2015-10-01            277.929230            213.160804            343.781728
# 2018-09-01            231.827240            140.619425            312.507595
#
#             post_preds_means  post_preds_lower  post_preds_upper  post_cum_y  \
# 2017-03-01        231.286179        165.498392        296.508292       424.0
# 2018-02-01        249.537109        167.281477        338.911945      1140.0
# 2016-02-01               NaN               NaN               NaN         NaN
# 2015-10-01               NaN               NaN               NaN         NaN
# 2018-09-01        231.827240        140.619425        312.507595      1655.0
#
#             post_cum_preds_means  post_cum_preds_lower  post_cum_preds_upper  \
# 2017-03-01            998.382507            863.010588           1145.997427
# 2018-02-01           3627.085205           3302.039630           3985.704462
# 2016-02-01                   NaN                   NaN                   NaN
# 2015-10-01                   NaN                   NaN                   NaN
# 2018-09-01           5285.974609           4824.771851           5801.233777
#
#             point_effects_means  point_effects_lower  point_effects_upper  \
# 2017-03-01          -153.286179          -218.508292           -87.498392
# 2018-02-01          -189.537109          -278.911945          -107.281477
# 2016-02-01             4.101624           -63.816945            66.072204
# 2015-10-01           -30.929230           -96.781728            33.839196
# 2018-09-01          -169.827240          -250.507595           -78.619425
#
#             post_cum_effects_means  post_cum_effects_lower  \
# 2017-03-01             -574.382507             -721.997429
# 2018-02-01            -2487.085693            -2845.704456
# 2016-02-01                     NaN                     NaN
# 2015-10-01                     NaN                     NaN
# 2018-09-01            -3630.975098            -4146.233777
#
#             post_cum_effects_upper
# 2017-03-01             -439.010558
# 2018-02-01            -2162.039624
# 2016-02-01                     NaN
# 2015-10-01                     NaN
# 2018-09-01            -3169.771350

# %%
print(ci.summary('report'))
# Out:
# Analysis report {CausalImpact}
#
#
# During the post-intervention period, the response variable had
# an average value of approx. 74.4. By contrast, in the absence of an
# intervention, we would have expected an average response of 239.83.
# The 95% interval of this counterfactual prediction is [217.72, 263.12].
# Subtracting this prediction from the observed response yields
# an estimate of the causal effect the intervention had on the
# response variable. This effect is -165.43 with a 95% interval of
# [-188.72, -143.32]. For a discussion of the significance of this effect,
# see below.
#
#
# Summing up the individual data points during the post-intervention
# period (which can only sometimes be meaningfully interpreted), the
# response variable had an overall value of 1860.0.
# By contrast, had the intervention not taken place, we would have expected
# a sum of 5995.7. The 95% interval of this prediction is [5442.97, 6577.98].
#
#
# The above results are given in terms of absolute numbers. In relative
# terms, the response variable showed a decrease of -68.98%. The 95%
# interval of this percentage is [-78.69%, -59.76%].
#
#
# This means that the negative effect observed during the intervention
# period is statistically significant.
# If the experimenter had expected a positive effect, it is recommended
# to double-check whether anomalies in the control variables may have
# caused an overly optimistic expectation of what should have happened
# in the response variable in the absence of the intervention.
#
#
# The probability of obtaining this effect by chance is very small
# (Bayesian one-sided tail-area probability p = 0.0).
# This means the causal effect can be considered statistically
# significant.
