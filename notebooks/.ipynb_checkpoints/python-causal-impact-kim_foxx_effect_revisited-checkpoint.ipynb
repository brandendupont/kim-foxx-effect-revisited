# %% [markdown]
# # Kim Foxx Effect Revisited

# %% [markdown]
# Kim Foxx's office's unprecedented release of 6 years of case-level data provided the opportunity
# for the Marshall Project to investigate the effect of Foxx's policy. In a discussion of data and
# methods the author, Matt Daniels, finishes with a nod to the limitations of his approach: “The aim of this project
# was not to find an absolute figure for a progressive prosecutor’s impact, but rather a rough
# estimate of how  Foxx’s policies affect the people of Cook County.”
#
# The purpose of this study is to provide a precise estimate on the effect of progressive
# prosecutorial policies under Kim Foxx in Cook County, Illinois. Currently, it is the only county in
# the United States that has publicly released case-level data at the intake stage, i.e. when county
# prosecutors decide how aggressively to pursue charges.
#
# We employ two versions of a Bayesian structural time-series (BSTS) developed by (Brodersen et al., 2015) to estimate the number of cases Foxx’s office turned away that would have
# been pursued by previous State’s Attorney Anita Alvarez. We model the first as a single time series w/o controls. In the second, we add time series covariated to improve the model.
#
#
# 1. Model an interrupted time series w/o control, single-pre/post design using a BSTS
#     1. Overall felony cases
#     2. Overall  retail theft
#     4. Overall misdemeanor retail theft
#     5. Overall felony retail theft
#
# The BSTS model recommends adding time-series corvariates that are predictive to our outcome of interest (number of charges issued), but not affected by the intervention that took place (Kim Foxx's decision to decline or lessen charges) when training the model. We add the covariates, weather, holidays, and reported incidents. {cite Campedelli}. **will need to add a longer discussion on controls**
#
# 2. Model an interrupted time series synthethic control using Python port of Causal Impact
#
#     Covariates
#     1. reported incidents of retail thefts
#     2. temperature
#     3. holidays
#
#
# We will explore threats to validity,
# hypothesis tests, and various model diagnostics to provide a sense of confidence around our
# findings.
#
# Datasets

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
from causalimpact import CausalImpact
from causalimpact.misc import standardize
import matplotlib
import seaborn as sns
import requests as r
from statsmodels.tsa.seasonal import seasonal_decompose
import tensorflow_probability as tfp
import tensorflow as tf
import datetime

# %%
import statsmodels.api as sm

# %%
# %matplotlib inline
# add some basic matplotlib defaults
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = (15, 6)
# set plot size and type to ggplot
plt.rcParams['figure.figsize']=(20,10)
plt.style.use('ggplot')

# %% [markdown]
# ### Import Data
#
# Get charge initatiations data from the Circuit. An overview of the data source can be found [here](https://charges.thecircuit.cc/en/methodology/).

# %%
# fetch theft data
cc = r.get('https://charges.thecircuit.cc/page-data/en/theft/page-data.json').json()

# %%
# select data results
cc['result']['data']['Courts']['analysis_charge_counts_by_month_stacked']
# Out:
# [{'case_date': 946684800,
#   'charges_f': 0,
#   'charges_m': 80,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 946684800,
#   'charges_f': 269,
#   'charges_m': 1096,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 946684800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 946684800,
#   'charges_f': 0,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 946684800,
#   'charges_f': 86,
#   'charges_m': 332,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 949363200,
#   'charges_f': 135,
#   'charges_m': 308,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 949363200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 949363200,
#   'charges_f': 0,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 949363200,
#   'charges_f': 1,
#   'charges_m': 91,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 949363200,
#   'charges_f': 240,
#   'charges_m': 1042,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 951868800,
#   'charges_f': 261,
#   'charges_m': 1386,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 951868800,
#   'charges_f': 122,
#   'charges_m': 403,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 951868800,
#   'charges_f': 0,
#   'charges_m': 4,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 951868800,
#   'charges_f': 1,
#   'charges_m': 112,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 951868800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 954547200,
#   'charges_f': 0,
#   'charges_m': 1,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 954547200,
#   'charges_f': 111,
#   'charges_m': 308,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 954547200,
#   'charges_f': 0,
#   'charges_m': 83,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 954547200,
#   'charges_f': 206,
#   'charges_m': 1115,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 954547200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 957139200,
#   'charges_f': 0,
#   'charges_m': 109,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 957139200,
#   'charges_f': 118,
#   'charges_m': 329,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 957139200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 957139200,
#   'charges_f': 3,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 957139200,
#   'charges_f': 220,
#   'charges_m': 1406,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 959817600,
#   'charges_f': 221,
#   'charges_m': 1470,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 959817600,
#   'charges_f': 1,
#   'charges_m': 121,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 959817600,
#   'charges_f': 0,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 959817600,
#   'charges_f': 171,
#   'charges_m': 414,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 959817600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 962409600,
#   'charges_f': 0,
#   'charges_m': 5,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 962409600,
#   'charges_f': 251,
#   'charges_m': 1261,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 962409600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 962409600,
#   'charges_f': 0,
#   'charges_m': 123,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 962409600,
#   'charges_f': 120,
#   'charges_m': 446,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 965088000,
#   'charges_f': 1,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 965088000,
#   'charges_f': 0,
#   'charges_m': 138,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 965088000,
#   'charges_f': 197,
#   'charges_m': 414,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 965088000,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 965088000,
#   'charges_f': 245,
#   'charges_m': 1310,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 967766400,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 967766400,
#   'charges_f': 0,
#   'charges_m': 110,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 967766400,
#   'charges_f': 156,
#   'charges_m': 352,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 967766400,
#   'charges_f': 231,
#   'charges_m': 1139,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 967766400,
#   'charges_f': 0,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 970358400,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 970358400,
#   'charges_f': 150,
#   'charges_m': 392,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 970358400,
#   'charges_f': 1,
#   'charges_m': 109,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 970358400,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 970358400,
#   'charges_f': 245,
#   'charges_m': 1400,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 973036800,
#   'charges_f': 139,
#   'charges_m': 357,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 973036800,
#   'charges_f': 0,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 973036800,
#   'charges_f': 0,
#   'charges_m': 84,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 973036800,
#   'charges_f': 255,
#   'charges_m': 1390,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 973036800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 975628800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 975628800,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 975628800,
#   'charges_f': 232,
#   'charges_m': 1445,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 975628800,
#   'charges_f': 120,
#   'charges_m': 302,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 975628800,
#   'charges_f': 0,
#   'charges_m': 67,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 978307200,
#   'charges_f': 0,
#   'charges_m': 61,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 978307200,
#   'charges_f': 118,
#   'charges_m': 389,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 978307200,
#   'charges_f': 249,
#   'charges_m': 1477,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 978307200,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 978307200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 980985600,
#   'charges_f': 1,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 980985600,
#   'charges_f': 3,
#   'charges_m': 73,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 980985600,
#   'charges_f': 218,
#   'charges_m': 1126,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 980985600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 980985600,
#   'charges_f': 114,
#   'charges_m': 295,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 983404800,
#   'charges_f': 141,
#   'charges_m': 349,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 983404800,
#   'charges_f': 1,
#   'charges_m': 7,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 983404800,
#   'charges_f': 265,
#   'charges_m': 1267,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 983404800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 983404800,
#   'charges_f': 1,
#   'charges_m': 83,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 986083200,
#   'charges_f': 0,
#   'charges_m': 76,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 986083200,
#   'charges_f': 219,
#   'charges_m': 1125,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 986083200,
#   'charges_f': 0,
#   'charges_m': 7,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 986083200,
#   'charges_f': 112,
#   'charges_m': 343,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 986083200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 988675200,
#   'charges_f': 157,
#   'charges_m': 363,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 988675200,
#   'charges_f': 0,
#   'charges_m': 118,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 988675200,
#   'charges_f': 0,
#   'charges_m': 7,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 988675200,
#   'charges_f': 246,
#   'charges_m': 1178,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 988675200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 991353600,
#   'charges_f': 0,
#   'charges_m': 5,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 991353600,
#   'charges_f': 222,
#   'charges_m': 1238,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 991353600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 991353600,
#   'charges_f': 181,
#   'charges_m': 367,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 991353600,
#   'charges_f': 1,
#   'charges_m': 87,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 993945600,
#   'charges_f': 0,
#   'charges_m': 111,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 993945600,
#   'charges_f': 3,
#   'charges_m': 5,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 993945600,
#   'charges_f': 155,
#   'charges_m': 426,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 993945600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 993945600,
#   'charges_f': 254,
#   'charges_m': 1161,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 996624000,
#   'charges_f': 283,
#   'charges_m': 1394,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 996624000,
#   'charges_f': 0,
#   'charges_m': 114,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 996624000,
#   'charges_f': 1,
#   'charges_m': 10,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 996624000,
#   'charges_f': 161,
#   'charges_m': 438,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 996624000,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 999302400,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 999302400,
#   'charges_f': 149,
#   'charges_m': 339,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 999302400,
#   'charges_f': 1,
#   'charges_m': 10,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 999302400,
#   'charges_f': 2,
#   'charges_m': 79,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 999302400,
#   'charges_f': 218,
#   'charges_m': 1150,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1001894400,
#   'charges_f': 295,
#   'charges_m': 1567,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1001894400,
#   'charges_f': 0,
#   'charges_m': 3,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1001894400,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1001894400,
#   'charges_f': 1,
#   'charges_m': 132,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1001894400,
#   'charges_f': 153,
#   'charges_m': 415,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1004572800,
#   'charges_f': 334,
#   'charges_m': 1184,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1004572800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1004572800,
#   'charges_f': 1,
#   'charges_m': 120,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1004572800,
#   'charges_f': 168,
#   'charges_m': 285,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1004572800,
#   'charges_f': 0,
#   'charges_m': 3,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1007164800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1007164800,
#   'charges_f': 128,
#   'charges_m': 358,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1007164800,
#   'charges_f': 0,
#   'charges_m': 85,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1007164800,
#   'charges_f': 0,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1007164800,
#   'charges_f': 357,
#   'charges_m': 1191,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1009843200,
#   'charges_f': 1,
#   'charges_m': 109,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1009843200,
#   'charges_f': 388,
#   'charges_m': 1347,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1009843200,
#   'charges_f': 143,
#   'charges_m': 330,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1009843200,
#   'charges_f': 0,
#   'charges_m': 5,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1009843200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1012521600,
#   'charges_f': 311,
#   'charges_m': 976,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1012521600,
#   'charges_f': 0,
#   'charges_m': 97,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1012521600,
#   'charges_f': 114,
#   'charges_m': 256,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1012521600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1012521600,
#   'charges_f': 0,
#   'charges_m': 3,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1014940800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1014940800,
#   'charges_f': 1,
#   'charges_m': 5,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1014940800,
#   'charges_f': 302,
#   'charges_m': 1159,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1014940800,
#   'charges_f': 127,
#   'charges_m': 329,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1014940800,
#   'charges_f': 1,
#   'charges_m': 104,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1017619200,
#   'charges_f': 325,
#   'charges_m': 1124,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1017619200,
#   'charges_f': 2,
#   'charges_m': 6,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1017619200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1017619200,
#   'charges_f': 0,
#   'charges_m': 108,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1017619200,
#   'charges_f': 141,
#   'charges_m': 325,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1020211200,
#   'charges_f': 124,
#   'charges_m': 298,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1020211200,
#   'charges_f': 1,
#   'charges_m': 77,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1020211200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1020211200,
#   'charges_f': 0,
#   'charges_m': 6,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1020211200,
#   'charges_f': 335,
#   'charges_m': 1133,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1022889600,
#   'charges_f': 1,
#   'charges_m': 4,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1022889600,
#   'charges_f': 152,
#   'charges_m': 368,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1022889600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1022889600,
#   'charges_f': 0,
#   'charges_m': 107,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1022889600,
#   'charges_f': 306,
#   'charges_m': 1035,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1025481600,
#   'charges_f': 316,
#   'charges_m': 1077,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1025481600,
#   'charges_f': 3,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1025481600,
#   'charges_f': 122,
#   'charges_m': 352,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1025481600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1025481600,
#   'charges_f': 0,
#   'charges_m': 93,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1028160000,
#   'charges_f': 0,
#   'charges_m': 6,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1028160000,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1028160000,
#   'charges_f': 137,
#   'charges_m': 384,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1028160000,
#   'charges_f': 1,
#   'charges_m': 102,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1028160000,
#   'charges_f': 324,
#   'charges_m': 1057,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1030838400,
#   'charges_f': 0,
#   'charges_m': 98,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1030838400,
#   'charges_f': 1,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1030838400,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1030838400,
#   'charges_f': 281,
#   'charges_m': 981,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1030838400,
#   'charges_f': 106,
#   'charges_m': 327,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1033430400,
#   'charges_f': 135,
#   'charges_m': 371,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1033430400,
#   'charges_f': 0,
#   'charges_m': 103,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1033430400,
#   'charges_f': 0,
#   'charges_m': 5,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1033430400,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1033430400,
#   'charges_f': 363,
#   'charges_m': 1146,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1036108800,
#   'charges_f': 0,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1036108800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1036108800,
#   'charges_f': 253,
#   'charges_m': 890,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1036108800,
#   'charges_f': 0,
#   'charges_m': 63,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1036108800,
#   'charges_f': 73,
#   'charges_m': 289,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1038700800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1038700800,
#   'charges_f': 367,
#   'charges_m': 1233,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1038700800,
#   'charges_f': 0,
#   'charges_m': 1,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1038700800,
#   'charges_f': 0,
#   'charges_m': 87,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1038700800,
#   'charges_f': 129,
#   'charges_m': 317,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1041379200,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1041379200,
#   'charges_f': 1,
#   'charges_m': 59,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1041379200,
#   'charges_f': 97,
#   'charges_m': 307,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1041379200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1041379200,
#   'charges_f': 317,
#   'charges_m': 1054,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1044057600,
#   'charges_f': 261,
#   'charges_m': 952,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1044057600,
#   'charges_f': 1,
#   'charges_m': 85,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1044057600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1044057600,
#   'charges_f': 94,
#   'charges_m': 262,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1044057600,
#   'charges_f': 1,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1046476800,
#   'charges_f': 0,
#   'charges_m': 1,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1046476800,
#   'charges_f': 285,
#   'charges_m': 973,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1046476800,
#   'charges_f': 1,
#   'charges_m': 67,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1046476800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1046476800,
#   'charges_f': 85,
#   'charges_m': 269,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1049155200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1049155200,
#   'charges_f': 82,
#   'charges_m': 336,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1049155200,
#   'charges_f': 307,
#   'charges_m': 1067,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1049155200,
#   'charges_f': 0,
#   'charges_m': 3,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1049155200,
#   'charges_f': 0,
#   'charges_m': 81,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1051747200,
#   'charges_f': 98,
#   'charges_m': 318,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1051747200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1051747200,
#   'charges_f': 0,
#   'charges_m': 73,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1051747200,
#   'charges_f': 291,
#   'charges_m': 1043,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1051747200,
#   'charges_f': 1,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1054425600,
#   'charges_f': 0,
#   'charges_m': 87,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1054425600,
#   'charges_f': 297,
#   'charges_m': 921,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1054425600,
#   'charges_f': 90,
#   'charges_m': 348,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1054425600,
#   'charges_f': 0,
#   'charges_m': 5,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1054425600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1057017600,
#   'charges_f': 0,
#   'charges_m': 87,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1057017600,
#   'charges_f': 0,
#   'charges_m': 4,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1057017600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1057017600,
#   'charges_f': 285,
#   'charges_m': 981,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1057017600,
#   'charges_f': 95,
#   'charges_m': 386,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1059696000,
#   'charges_f': 0,
#   'charges_m': 1,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1059696000,
#   'charges_f': 307,
#   'charges_m': 911,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1059696000,
#   'charges_f': 1,
#   'charges_m': 101,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1059696000,
#   'charges_f': 94,
#   'charges_m': 377,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1059696000,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1062374400,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1062374400,
#   'charges_f': 101,
#   'charges_m': 388,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1062374400,
#   'charges_f': 0,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1062374400,
#   'charges_f': 0,
#   'charges_m': 95,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1062374400,
#   'charges_f': 289,
#   'charges_m': 1002,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1064966400,
#   'charges_f': 301,
#   'charges_m': 1115,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1064966400,
#   'charges_f': 0,
#   'charges_m': 3,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1064966400,
#   'charges_f': 121,
#   'charges_m': 338,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1064966400,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1064966400,
#   'charges_f': 0,
#   'charges_m': 103,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1067644800,
#   'charges_f': 0,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1067644800,
#   'charges_f': 280,
#   'charges_m': 827,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1067644800,
#   'charges_f': 0,
#   'charges_m': 69,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1067644800,
#   'charges_f': 107,
#   'charges_m': 338,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1067644800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1070236800,
#   'charges_f': 1,
#   'charges_m': 1,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1070236800,
#   'charges_f': 93,
#   'charges_m': 331,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1070236800,
#   'charges_f': 0,
#   'charges_m': 94,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1070236800,
#   'charges_f': 305,
#   'charges_m': 1172,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1070236800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1072915200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1072915200,
#   'charges_f': 83,
#   'charges_m': 321,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1072915200,
#   'charges_f': 325,
#   'charges_m': 990,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1072915200,
#   'charges_f': 2,
#   'charges_m': 1,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1072915200,
#   'charges_f': 0,
#   'charges_m': 80,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1075593600,
#   'charges_f': 93,
#   'charges_m': 262,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1075593600,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1075593600,
#   'charges_f': 264,
#   'charges_m': 737,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1075593600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1075593600,
#   'charges_f': 0,
#   'charges_m': 63,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1078099200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1078099200,
#   'charges_f': 274,
#   'charges_m': 1039,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1078099200,
#   'charges_f': 0,
#   'charges_m': 57,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1078099200,
#   'charges_f': 126,
#   'charges_m': 311,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1078099200,
#   'charges_f': 0,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1080777600,
#   'charges_f': 0,
#   'charges_m': 3,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1080777600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1080777600,
#   'charges_f': 300,
#   'charges_m': 1005,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1080777600,
#   'charges_f': 0,
#   'charges_m': 66,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1080777600,
#   'charges_f': 86,
#   'charges_m': 328,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1083369600,
#   'charges_f': 1,
#   'charges_m': 67,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1083369600,
#   'charges_f': 0,
#   'charges_m': 4,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1083369600,
#   'charges_f': 80,
#   'charges_m': 296,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1083369600,
#   'charges_f': 230,
#   'charges_m': 870,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1083369600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1086048000,
#   'charges_f': 1,
#   'charges_m': 1,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1086048000,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1086048000,
#   'charges_f': 0,
#   'charges_m': 68,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1086048000,
#   'charges_f': 259,
#   'charges_m': 995,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1086048000,
#   'charges_f': 120,
#   'charges_m': 385,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1088640000,
#   'charges_f': 90,
#   'charges_m': 387,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1088640000,
#   'charges_f': 269,
#   'charges_m': 913,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1088640000,
#   'charges_f': 0,
#   'charges_m': 4,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1088640000,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1088640000,
#   'charges_f': 0,
#   'charges_m': 92,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1091318400,
#   'charges_f': 0,
#   'charges_m': 73,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1091318400,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1091318400,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1091318400,
#   'charges_f': 130,
#   'charges_m': 402,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1091318400,
#   'charges_f': 267,
#   'charges_m': 940,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1093996800,
#   'charges_f': 270,
#   'charges_m': 895,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1093996800,
#   'charges_f': 0,
#   'charges_m': 81,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1093996800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1093996800,
#   'charges_f': 0,
#   'charges_m': 4,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1093996800,
#   'charges_f': 112,
#   'charges_m': 396,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1096588800,
#   'charges_f': 264,
#   'charges_m': 934,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1096588800,
#   'charges_f': 0,
#   'charges_m': 89,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1096588800,
#   'charges_f': 0,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1096588800,
#   'charges_f': 128,
#   'charges_m': 311,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1096588800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1099267200,
#   'charges_f': 1,
#   'charges_m': 66,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1099267200,
#   'charges_f': 252,
#   'charges_m': 835,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1099267200,
#   'charges_f': 82,
#   'charges_m': 281,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1099267200,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1099267200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1101859200,
#   'charges_f': 0,
#   'charges_m': 4,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1101859200,
#   'charges_f': 270,
#   'charges_m': 978,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1101859200,
#   'charges_f': 1,
#   'charges_m': 77,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1101859200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1101859200,
#   'charges_f': 126,
#   'charges_m': 357,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1104537600,
#   'charges_f': 0,
#   'charges_m': 50,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1104537600,
#   'charges_f': 0,
#   'charges_m': 4,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1104537600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1104537600,
#   'charges_f': 72,
#   'charges_m': 297,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1104537600,
#   'charges_f': 286,
#   'charges_m': 871,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1107216000,
#   'charges_f': 206,
#   'charges_m': 710,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1107216000,
#   'charges_f': 0,
#   'charges_m': 49,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1107216000,
#   'charges_f': 98,
#   'charges_m': 244,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1107216000,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1107216000,
#   'charges_f': 1,
#   'charges_m': 3,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1109635200,
#   'charges_f': 0,
#   'charges_m': 3,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1109635200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1109635200,
#   'charges_f': 224,
#   'charges_m': 896,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1109635200,
#   'charges_f': 127,
#   'charges_m': 320,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1109635200,
#   'charges_f': 0,
#   'charges_m': 73,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1112313600,
#   'charges_f': 1,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1112313600,
#   'charges_f': 0,
#   'charges_m': 60,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1112313600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1112313600,
#   'charges_f': 218,
#   'charges_m': 951,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1112313600,
#   'charges_f': 103,
#   'charges_m': 314,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1114905600,
#   'charges_f': 0,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1114905600,
#   'charges_f': 0,
#   'charges_m': 58,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1114905600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1114905600,
#   'charges_f': 100,
#   'charges_m': 343,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1114905600,
#   'charges_f': 245,
#   'charges_m': 702,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1117584000,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1117584000,
#   'charges_f': 1,
#   'charges_m': 87,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1117584000,
#   'charges_f': 107,
#   'charges_m': 373,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1117584000,
#   'charges_f': 258,
#   'charges_m': 986,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1117584000,
#   'charges_f': 0,
#   'charges_m': 6,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1120176000,
#   'charges_f': 90,
#   'charges_m': 341,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1120176000,
#   'charges_f': 192,
#   'charges_m': 798,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1120176000,
#   'charges_f': 0,
#   'charges_m': 5,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1120176000,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1120176000,
#   'charges_f': 0,
#   'charges_m': 100,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1122854400,
#   'charges_f': 244,
#   'charges_m': 910,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1122854400,
#   'charges_f': 110,
#   'charges_m': 383,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1122854400,
#   'charges_f': 2,
#   'charges_m': 4,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1122854400,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1122854400,
#   'charges_f': 1,
#   'charges_m': 93,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1125532800,
#   'charges_f': 145,
#   'charges_m': 393,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1125532800,
#   'charges_f': 208,
#   'charges_m': 918,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1125532800,
#   'charges_f': 0,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1125532800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1125532800,
#   'charges_f': 1,
#   'charges_m': 119,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1128124800,
#   'charges_f': 0,
#   'charges_m': 79,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1128124800,
#   'charges_f': 81,
#   'charges_m': 309,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1128124800,
#   'charges_f': 0,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1128124800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1128124800,
#   'charges_f': 212,
#   'charges_m': 796,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1130803200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1130803200,
#   'charges_f': 141,
#   'charges_m': 314,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1130803200,
#   'charges_f': 2,
#   'charges_m': 13,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1130803200,
#   'charges_f': 243,
#   'charges_m': 913,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1130803200,
#   'charges_f': 0,
#   'charges_m': 75,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1133395200,
#   'charges_f': 0,
#   'charges_m': 4,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1133395200,
#   'charges_f': 102,
#   'charges_m': 299,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1133395200,
#   'charges_f': 2,
#   'charges_m': 64,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1133395200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1133395200,
#   'charges_f': 271,
#   'charges_m': 955,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1136073600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1136073600,
#   'charges_f': 80,
#   'charges_m': 302,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1136073600,
#   'charges_f': 0,
#   'charges_m': 5,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1136073600,
#   'charges_f': 274,
#   'charges_m': 876,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1136073600,
#   'charges_f': 0,
#   'charges_m': 71,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1138752000,
#   'charges_f': 0,
#   'charges_m': 7,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1138752000,
#   'charges_f': 186,
#   'charges_m': 695,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1138752000,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1138752000,
#   'charges_f': 0,
#   'charges_m': 46,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1138752000,
#   'charges_f': 80,
#   'charges_m': 299,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1141171200,
#   'charges_f': 0,
#   'charges_m': 47,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1141171200,
#   'charges_f': 107,
#   'charges_m': 329,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1141171200,
#   'charges_f': 0,
#   'charges_m': 5,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1141171200,
#   'charges_f': 211,
#   'charges_m': 871,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1141171200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1143849600,
#   'charges_f': 183,
#   'charges_m': 659,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1143849600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1143849600,
#   'charges_f': 76,
#   'charges_m': 278,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1143849600,
#   'charges_f': 0,
#   'charges_m': 56,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1143849600,
#   'charges_f': 1,
#   'charges_m': 1,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1146441600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1146441600,
#   'charges_f': 1,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1146441600,
#   'charges_f': 196,
#   'charges_m': 764,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1146441600,
# ...
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1404172800,
#   'charges_f': 257,
#   'charges_m': 587,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1404172800,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1406851200,
#   'charges_f': 125,
#   'charges_m': 214,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1406851200,
#   'charges_f': 1,
#   'charges_m': 49,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1406851200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1406851200,
#   'charges_f': 3,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1406851200,
#   'charges_f': 262,
#   'charges_m': 555,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1409529600,
#   'charges_f': 276,
#   'charges_m': 610,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1409529600,
#   'charges_f': 121,
#   'charges_m': 203,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1409529600,
#   'charges_f': 0,
#   'charges_m': 59,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1409529600,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1409529600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1412121600,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1412121600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1412121600,
#   'charges_f': 282,
#   'charges_m': 523,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1412121600,
#   'charges_f': 103,
#   'charges_m': 180,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1412121600,
#   'charges_f': 0,
#   'charges_m': 71,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1414800000,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1414800000,
#   'charges_f': 0,
#   'charges_m': 38,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1414800000,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1414800000,
#   'charges_f': 256,
#   'charges_m': 456,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1414800000,
#   'charges_f': 70,
#   'charges_m': 149,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1417392000,
#   'charges_f': 97,
#   'charges_m': 178,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1417392000,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1417392000,
#   'charges_f': 282,
#   'charges_m': 630,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1417392000,
#   'charges_f': 0,
#   'charges_m': 55,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1417392000,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1420070400,
#   'charges_f': 98,
#   'charges_m': 142,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1420070400,
#   'charges_f': 0,
#   'charges_m': 37,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1420070400,
#   'charges_f': 282,
#   'charges_m': 576,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1420070400,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1420070400,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1422748800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1422748800,
#   'charges_f': 272,
#   'charges_m': 363,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1422748800,
#   'charges_f': 60,
#   'charges_m': 134,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1422748800,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1422748800,
#   'charges_f': 0,
#   'charges_m': 34,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1425168000,
#   'charges_f': 95,
#   'charges_m': 126,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1425168000,
#   'charges_f': 253,
#   'charges_m': 493,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1425168000,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1425168000,
#   'charges_f': 0,
#   'charges_m': 28,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1425168000,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1427846400,
#   'charges_f': 0,
#   'charges_m': 2,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1427846400,
#   'charges_f': 61,
#   'charges_m': 139,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1427846400,
#   'charges_f': 255,
#   'charges_m': 456,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1427846400,
#   'charges_f': 0,
#   'charges_m': 36,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1427846400,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1430438400,
#   'charges_f': 223,
#   'charges_m': 427,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1430438400,
#   'charges_f': 0,
#   'charges_m': 39,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1430438400,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1430438400,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1430438400,
#   'charges_f': 84,
#   'charges_m': 113,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1433116800,
#   'charges_f': 1,
#   'charges_m': 37,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1433116800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1433116800,
#   'charges_f': 0,
#   'charges_m': 3,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1433116800,
#   'charges_f': 237,
#   'charges_m': 531,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1433116800,
#   'charges_f': 77,
#   'charges_m': 170,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1435708800,
#   'charges_f': 1,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1435708800,
#   'charges_f': 88,
#   'charges_m': 163,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1435708800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1435708800,
#   'charges_f': 0,
#   'charges_m': 54,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1435708800,
#   'charges_f': 258,
#   'charges_m': 538,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1438387200,
#   'charges_f': 258,
#   'charges_m': 499,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1438387200,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1438387200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1438387200,
#   'charges_f': 1,
#   'charges_m': 52,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1438387200,
#   'charges_f': 102,
#   'charges_m': 172,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1441065600,
#   'charges_f': None,
#   'charges_m': 1,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1441065600,
#   'charges_f': 0,
#   'charges_m': 1,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1441065600,
#   'charges_f': 1,
#   'charges_m': 46,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1441065600,
#   'charges_f': 268,
#   'charges_m': 448,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1441065600,
#   'charges_f': 81,
#   'charges_m': 158,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1443657600,
#   'charges_f': 77,
#   'charges_m': 162,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1443657600,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1443657600,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1443657600,
#   'charges_f': 247,
#   'charges_m': 570,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1443657600,
#   'charges_f': 1,
#   'charges_m': 37,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1446336000,
#   'charges_f': 0,
#   'charges_m': 38,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1446336000,
#   'charges_f': 0,
#   'charges_m': 1,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1446336000,
#   'charges_f': 79,
#   'charges_m': 119,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1446336000,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1446336000,
#   'charges_f': 227,
#   'charges_m': 469,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1448928000,
#   'charges_f': 84,
#   'charges_m': 113,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1448928000,
#   'charges_f': 284,
#   'charges_m': 635,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1448928000,
#   'charges_f': 1,
#   'charges_m': 32,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1448928000,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1448928000,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1451606400,
#   'charges_f': 1,
#   'charges_m': 17,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1451606400,
#   'charges_f': 236,
#   'charges_m': 524,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1451606400,
#   'charges_f': 70,
#   'charges_m': 129,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1451606400,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1451606400,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1454284800,
#   'charges_f': 67,
#   'charges_m': 127,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1454284800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1454284800,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1454284800,
#   'charges_f': 256,
#   'charges_m': 506,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1454284800,
#   'charges_f': 0,
#   'charges_m': 32,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1456790400,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1456790400,
#   'charges_f': 0,
#   'charges_m': 28,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1456790400,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1456790400,
#   'charges_f': 72,
#   'charges_m': 104,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1456790400,
#   'charges_f': 229,
#   'charges_m': 547,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1459468800,
#   'charges_f': 227,
#   'charges_m': 516,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1459468800,
#   'charges_f': 76,
#   'charges_m': 101,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1459468800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1459468800,
#   'charges_f': 1,
#   'charges_m': 19,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1459468800,
#   'charges_f': 0,
#   'charges_m': 1,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1462060800,
#   'charges_f': 258,
#   'charges_m': 539,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1462060800,
#   'charges_f': 81,
#   'charges_m': 127,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1462060800,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1462060800,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1462060800,
#   'charges_f': 1,
#   'charges_m': 30,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1464739200,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1464739200,
#   'charges_f': 74,
#   'charges_m': 135,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1464739200,
#   'charges_f': 262,
#   'charges_m': 585,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1464739200,
#   'charges_f': 0,
#   'charges_m': 34,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1464739200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1467331200,
#   'charges_f': None,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  {'case_date': 1467331200,
#   'charges_f': 77,
#   'charges_m': 116,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1467331200,
#   'charges_f': 219,
#   'charges_m': 414,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1467331200,
#   'charges_f': 0,
#   'charges_m': 0,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1467331200,
#   'charges_f': 0,
#   'charges_m': 29,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1470009600,
#   'charges_f': 0,
#   'charges_m': 30,
#   'ucr': {'charge_slug': '50-theft-of-lost-or-mislaid-property'}},
#  {'case_date': 1470009600,
#   'charges_f': 0,
#   'charges_m': 3,
#   'ucr': {'charge_slug': '59-theft-from-coin-operated-machine-or-device'}},
#  {'case_date': 1470009600,
#   'charges_f': 219,
#   'charges_m': 561,
#   'ucr': {'charge_slug': '54-retail-theft'}},
#  {'case_date': 1470009600,
#   'charges_f': 84,
#   'charges_m': 165,
#   'ucr': {'charge_slug': '58-theft-from-building'}},
#  {'case_date': 1470009600,
#   'charges_f': None,
#   'charges_m': 1,
#   'ucr': {'charge_slug': '55-delivery-container-theft'}},
#  ...]

# %% [markdown]
# Convert returned json to DataFrame

# %%
theft = pd.DataFrame(cc['result']['data']['Courts']['analysis_charge_counts_by_month_stacked'])

# %% [markdown]
# Add offense type and remove number prefix

# %%
theft['offense_type'] = theft['ucr'].map(lambda x: list(dict(x).values())[0]).str.replace('\d+', '').str.replace("-", " ").str.strip()
# Out:
# <ipython-input-9-3c6e3b1998a2>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   theft['offense_type'] = theft['ucr'].map(lambda x: list(dict(x).values())[0]).str.replace('\d+', '').str.replace("-", " ").str.strip()

# %% [markdown]
# Convert data from unix to readable date.

# %%
theft['case_date'] = pd.to_datetime(theft['case_date'],unit='s')

# %% [markdown]
# Add Felony & Misdemeanor total

# %%
theft['charges_fm'] = theft['charges_f'] + theft['charges_m']

# %% [markdown]
# ### Save Data Locally

# %%
##theft.to_csv(r'C:\Users\brand\OneDrive\Documents\grad-school\pui\kim-fox-effect-revisited\data\theft_data_the_circuit_2000-2018.csv')

# %% [markdown]
# ### Subset data for analysis
#
# We will only include retail theft and the Kim Fox Effect timeline

# %%
rt = theft[(theft['offense_type'] == 'retail theft') & (theft['case_date'].dt.year >= 2012)]

# %% [markdown]
# ### Add Weather, Unemployment, Overall Charges, and Incidents

# %%
weather = pd.read_csv(r'C:\Users\brand\OneDrive\Documents\grad-school\pui\kim-fox-effect-revisited\data\weather_data_tomerge.csv',parse_dates=['month_dt']).set_index('month_dt')

# %%
unemploy = pd.read_csv(r'C:\Users\brand\OneDrive\Documents\grad-school\pui\kim-fox-effect-revisited\data\unemployment_data_tomerge.csv', parse_dates=['month_dt']).set_index('month_dt')

# %%
overall_charges = pd.read_csv(r'C:\Users\brand\OneDrive\Documents\grad-school\pui\kim-fox-effect-revisited\data\overall-charges.csv',).rename(columns={'cases':'total_charges'})

# %% [markdown]
# Fix overall charges

# %%
overall_charges['date'] = pd.to_datetime(overall_charges['date']).apply(lambda s: datetime.date(s.year, s.month, 1))
overall_charges = overall_charges.set_index('date')

# %% [markdown]
# Import Chicago Incidents

# %%
inc_2014 = pd.read_csv(r'C:\Users\brand\Downloads\Crimes_-_2014.csv')
inc_2015 = pd.read_csv(r'C:\Users\brand\Downloads\Crimes_-_2015.csv')
inc_2016 = pd.read_csv(r'C:\Users\brand\Downloads\Crimes_-_2016.csv')
inc_2017 = pd.read_csv(r'C:\Users\brand\Downloads\Crimes_-_2017.csv')
inc_2018 = pd.read_csv(r'C:\Users\brand\Downloads\Crimes_-_2018.csv')

# %% [markdown]
# Get monthly overall incidents and monthly retail thefts.

# %%
inc = pd.concat([inc_2014,inc_2015, inc_2016,inc_2017, inc_2018])

# %% [markdown]
# Convert to datetime

# %%
inc['Date'] = pd.to_datetime(inc['Date'])

# %% [markdown]
# Get year month

# %%
inc['yr_month'] = inc['Date'].apply(lambda s: datetime.date(s.year, s.month, 1))

# %% [markdown]
# Assert no duplicated records

# %%
assert inc['ID'].duplicated().sum() == 0

# %%
overall_mn_inc = inc[(inc['Arrest'] == True) & (inc['Primary Type'] !="THEFT") \
                               & (inc['Description'] != 'RETAIL THEFT') ].groupby('yr_month')['ID'].count().reset_index(name='monthly_incidents_arrests').set_index('yr_month')

# %%
overall_mn_rt_inc = inc[(inc['Primary Type'] =="THEFT") & (inc['Description'] == 'RETAIL THEFT') ].groupby('yr_month')['ID'].count().reset_index(name='monthly_retail_theft').set_index('yr_month')

# %%
overall_mn_rt_inc = inc[(inc['Primary Type'] =="THEFT") & (inc['Description'] == 'RETAIL THEFT') ].groupby('yr_month')['ID'].count().reset_index(name='monthly_retail_theft').set_index('yr_month')

# %%
overall_mn_rt_inc_arrest = inc[(inc['Arrest'] == True) & (inc['Primary Type'] =="THEFT") \
                               & (inc['Description'] == 'RETAIL THEFT') ].groupby('yr_month')['ID'].count().reset_index(name='monthly_retail_theft_arrest').set_index('yr_month')

# %% [markdown]
# ### Join all Data

# %%
overall_charges
# Out:
#             total_charges
# date
# 2014-05-01           1940
# 2014-06-01           1941
# 2014-07-01           1979
# 2014-08-01           1916
# 2014-09-01           1831
# ...                   ...
# 2019-02-01           1289
# 2019-03-01           1408
# 2019-04-01           1503
# 2019-05-01           1620
# 2019-06-01           1489
#
# [62 rows x 1 columns]

# %%
data_final = rt.set_index('case_date').join([overall_mn_inc,overall_mn_rt_inc,overall_mn_rt_inc_arrest, overall_charges,unemploy[['Value']],weather[['PRCP','TAVG']]])

# %%
data_final = data_final[(data_final.index >= '2014-01-01') & (data_final.index <= '2018-12-01')]

# %%
data_final.to_csv(r'C:\Users\brand\OneDrive\Documents\grad-school\pui\kim-fox-effect-revisited\data\final_monthly_data.csv')

# %% [markdown]
# Subset to Only Include KFE Time Frame

# %% [markdown]
# ### Monthly Trends by Felony & Misdemeanor, Felony only, and Misdemeanor only

# %%
for charge_lvl in ['charges_fm', 'charges_f','charges_m']:
    rt.set_index('case_date')[charge_lvl].plot()

# %% [markdown]
# ### Year Retail Theft Trends by Felony & Misdemeanor, Felony only, and Misdemeanor only

# %%
for charge_lvl in ['charges_fm', 'charges_f','charges_m']:  
    rt.groupby(rt['case_date'].dt.year)[charge_lvl].sum().plot(legend=True)

# %% [markdown]
# ### Autocorrelation Plot

# %%
cim = rt[['case_date','charges_f' ]].set_index('case_date')

# %%
cim.index.max()
# Out:
# Timestamp('2018-12-01 00:00:00')

# %%
result = seasonal_decompose(cim[:'2016-11-01'])

additive_decomposition = seasonal_decompose(cim[:'2016-11-01'], model='additive', period=12)

# %%
final_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-418-c3c4c7ff6e78> in <module>
# ----> 1 final_data.head()
#
# NameError: name 'final_data' is not defined

# %% [markdown]
# ### Save Data

# %%
rt.to_csv()

# %%
cim.head()
# Out:
#             charges_f
# case_date
# 2012-01-01      227.0
# 2012-02-01      209.0
# 2012-03-01      215.0
# 2012-04-01      213.0
# 2012-05-01      208.0

# %% [markdown]
# # Run Causal Impact on Felony Thefts
#
# Review original Kim Foxx Effect methods [here](https://projects.chicagoreporter.com/kim-foxx-prosecutions-20191024/#method).
#
# Overview on model args [here](https://stats.stackexchange.com/questions/209426/predictions-from-bsts-model-in-r-are-failing-completely).
#
# This model uses default settings, we will later fit a custom sts [model](https://towardsdatascience.com/structural-time-series-forecasting-with-tensorflow-probability-iron-ore-mine-production-897d2334c72b)

# %%
data_final
# Out:
#             charges_f  charges_m                                 ucr  \
# case_date
# 2014-01-01      306.0      485.0  {'charge_slug': '54-retail-theft'}
# 2014-02-01      206.0      385.0  {'charge_slug': '54-retail-theft'}
# 2014-03-01      269.0      423.0  {'charge_slug': '54-retail-theft'}
# 2014-04-01      290.0      481.0  {'charge_slug': '54-retail-theft'}
# 2014-05-01      274.0      503.0  {'charge_slug': '54-retail-theft'}
# 2014-06-01      289.0      520.0  {'charge_slug': '54-retail-theft'}
# 2014-07-01      257.0      587.0  {'charge_slug': '54-retail-theft'}
# 2014-08-01      262.0      555.0  {'charge_slug': '54-retail-theft'}
# 2014-09-01      276.0      610.0  {'charge_slug': '54-retail-theft'}
# 2014-10-01      282.0      523.0  {'charge_slug': '54-retail-theft'}
# 2014-11-01      256.0      456.0  {'charge_slug': '54-retail-theft'}
# 2014-12-01      282.0      630.0  {'charge_slug': '54-retail-theft'}
# 2015-01-01      282.0      576.0  {'charge_slug': '54-retail-theft'}
# 2015-02-01      272.0      363.0  {'charge_slug': '54-retail-theft'}
# 2015-03-01      253.0      493.0  {'charge_slug': '54-retail-theft'}
# 2015-04-01      255.0      456.0  {'charge_slug': '54-retail-theft'}
# 2015-05-01      223.0      427.0  {'charge_slug': '54-retail-theft'}
# 2015-06-01      237.0      531.0  {'charge_slug': '54-retail-theft'}
# 2015-07-01      258.0      538.0  {'charge_slug': '54-retail-theft'}
# 2015-08-01      258.0      499.0  {'charge_slug': '54-retail-theft'}
# 2015-09-01      268.0      448.0  {'charge_slug': '54-retail-theft'}
# 2015-10-01      247.0      570.0  {'charge_slug': '54-retail-theft'}
# 2015-11-01      227.0      469.0  {'charge_slug': '54-retail-theft'}
# 2015-12-01      284.0      635.0  {'charge_slug': '54-retail-theft'}
# 2016-01-01      236.0      524.0  {'charge_slug': '54-retail-theft'}
# 2016-02-01      256.0      506.0  {'charge_slug': '54-retail-theft'}
# 2016-03-01      229.0      547.0  {'charge_slug': '54-retail-theft'}
# 2016-04-01      227.0      516.0  {'charge_slug': '54-retail-theft'}
# 2016-05-01      258.0      539.0  {'charge_slug': '54-retail-theft'}
# 2016-06-01      262.0      585.0  {'charge_slug': '54-retail-theft'}
# 2016-07-01      219.0      414.0  {'charge_slug': '54-retail-theft'}
# 2016-08-01      219.0      561.0  {'charge_slug': '54-retail-theft'}
# 2016-09-01      220.0      508.0  {'charge_slug': '54-retail-theft'}
# 2016-10-01      220.0      523.0  {'charge_slug': '54-retail-theft'}
# 2016-11-01      200.0      575.0  {'charge_slug': '54-retail-theft'}
# 2016-12-01      172.0      719.0  {'charge_slug': '54-retail-theft'}
# 2017-01-01       77.0      689.0  {'charge_slug': '54-retail-theft'}
# 2017-02-01       97.0      526.0  {'charge_slug': '54-retail-theft'}
# 2017-03-01       78.0      631.0  {'charge_slug': '54-retail-theft'}
# 2017-04-01       78.0      585.0  {'charge_slug': '54-retail-theft'}
# 2017-05-01       66.0      672.0  {'charge_slug': '54-retail-theft'}
# 2017-06-01       56.0      686.0  {'charge_slug': '54-retail-theft'}
# 2017-07-01       80.0      640.0  {'charge_slug': '54-retail-theft'}
# 2017-08-01       62.0      725.0  {'charge_slug': '54-retail-theft'}
# 2017-09-01       62.0      667.0  {'charge_slug': '54-retail-theft'}
# 2017-10-01       51.0      617.0  {'charge_slug': '54-retail-theft'}
# 2017-11-01       60.0      659.0  {'charge_slug': '54-retail-theft'}
# 2017-12-01       58.0      649.0  {'charge_slug': '54-retail-theft'}
# 2018-01-01       83.0      759.0  {'charge_slug': '54-retail-theft'}
# 2018-02-01       60.0      593.0  {'charge_slug': '54-retail-theft'}
# 2018-03-01       80.0      669.0  {'charge_slug': '54-retail-theft'}
# 2018-04-01       90.0      616.0  {'charge_slug': '54-retail-theft'}
# 2018-05-01       75.0      668.0  {'charge_slug': '54-retail-theft'}
# 2018-06-01       72.0      622.0  {'charge_slug': '54-retail-theft'}
# 2018-07-01       49.0      655.0  {'charge_slug': '54-retail-theft'}
# 2018-08-01       87.0      652.0  {'charge_slug': '54-retail-theft'}
# 2018-09-01       62.0      591.0  {'charge_slug': '54-retail-theft'}
# 2018-10-01       76.0      693.0  {'charge_slug': '54-retail-theft'}
# 2018-11-01       60.0      553.0  {'charge_slug': '54-retail-theft'}
# 2018-12-01       69.0      430.0  {'charge_slug': '54-retail-theft'}
#
#             offense_type  charges_fm  monthly_incidents_arrests  \
# case_date
# 2014-01-01  retail theft       791.0                     5748.0
# 2014-02-01  retail theft       591.0                     5820.0
# 2014-03-01  retail theft       692.0                     6823.0
# 2014-04-01  retail theft       771.0                     6817.0
# 2014-05-01  retail theft       777.0                     7372.0
# 2014-06-01  retail theft       809.0                     7130.0
# 2014-07-01  retail theft       844.0                     7609.0
# 2014-08-01  retail theft       817.0                     7329.0
# 2014-09-01  retail theft       886.0                     6757.0
# 2014-10-01  retail theft       805.0                     6861.0
# 2014-11-01  retail theft       712.0                     5856.0
# 2014-12-01  retail theft       912.0                     5483.0
# 2015-01-01  retail theft       858.0                     6183.0
# 2015-02-01  retail theft       635.0                     5156.0
# 2015-03-01  retail theft       746.0                     6602.0
# 2015-04-01  retail theft       711.0                     5957.0
# 2015-05-01  retail theft       650.0                     6311.0
# 2015-06-01  retail theft       768.0                     6006.0
# 2015-07-01  retail theft       796.0                     6293.0
# 2015-08-01  retail theft       757.0                     6248.0
# 2015-09-01  retail theft       716.0                     5921.0
# 2015-10-01  retail theft       817.0                     5920.0
# 2015-11-01  retail theft       696.0                     5090.0
# 2015-12-01  retail theft       919.0                     4320.0
# 2016-01-01  retail theft       760.0                     4261.0
# 2016-02-01  retail theft       762.0                     4233.0
# 2016-03-01  retail theft       776.0                     4921.0
# 2016-04-01  retail theft       743.0                     4962.0
# 2016-05-01  retail theft       797.0                     5190.0
# 2016-06-01  retail theft       847.0                     4963.0
# 2016-07-01  retail theft       633.0                     4619.0
# 2016-08-01  retail theft       780.0                     4201.0
# 2016-09-01  retail theft       728.0                     4207.0
# 2016-10-01  retail theft       743.0                     4082.0
# 2016-11-01  retail theft       775.0                     3787.0
# 2016-12-01  retail theft       891.0                     3568.0
# 2017-01-01  retail theft       766.0                     4280.0
# 2017-02-01  retail theft       623.0                     4080.0
# 2017-03-01  retail theft       709.0                     4401.0
# 2017-04-01  retail theft       663.0                     4539.0
# 2017-05-01  retail theft       738.0                     4875.0
# 2017-06-01  retail theft       742.0                     4606.0
# 2017-07-01  retail theft       720.0                     4802.0
# 2017-08-01  retail theft       787.0                     4672.0
# 2017-09-01  retail theft       729.0                     4355.0
# 2017-10-01  retail theft       668.0                     4143.0
# 2017-11-01  retail theft       719.0                     4020.0
# 2017-12-01  retail theft       707.0                     3818.0
# 2018-01-01  retail theft       842.0                     4227.0
# 2018-02-01  retail theft       653.0                     3891.0
# 2018-03-01  retail theft       749.0                     4603.0
# 2018-04-01  retail theft       706.0                     4284.0
# 2018-05-01  retail theft       743.0                     4978.0
# 2018-06-01  retail theft       694.0                     4599.0
# 2018-07-01  retail theft       704.0                     4853.0
# 2018-08-01  retail theft       739.0                     5005.0
# 2018-09-01  retail theft       653.0                     4580.0
# 2018-10-01  retail theft       769.0                     4326.0
# 2018-11-01  retail theft       613.0                     4227.0
# 2018-12-01  retail theft       499.0                     4234.0
#
#             monthly_retail_theft  monthly_retail_theft_arrest  total_charges  \
# case_date
# 2014-01-01                 567.0                        373.0            NaN
# 2014-02-01                 525.0                        354.0            NaN
# 2014-03-01                 629.0                        416.0            NaN
# 2014-04-01                 611.0                        416.0            NaN
# 2014-05-01                 704.0                        462.0         1940.0
# 2014-06-01                 679.0                        433.0         1941.0
# 2014-07-01                 773.0                        484.0         1979.0
# 2014-08-01                 743.0                        428.0         1916.0
# 2014-09-01                 669.0                        440.0         1831.0
# 2014-10-01                 713.0                        462.0         1850.0
# 2014-11-01                 663.0                        401.0         1658.0
# 2014-12-01                 690.0                        453.0         1630.0
# 2015-01-01                 717.0                        453.0         1811.0
# 2015-02-01                 539.0                        347.0         1532.0
# 2015-03-01                 652.0                        416.0         1769.0
# 2015-04-01                 659.0                        405.0         1660.0
# 2015-05-01                 738.0                        426.0         1785.0
# 2015-06-01                 718.0                        405.0         1672.0
# 2015-07-01                 780.0                        434.0         1918.0
# 2015-08-01                 753.0                        397.0         1840.0
# 2015-09-01                 711.0                        399.0         1853.0
# 2015-10-01                 736.0                        428.0         1788.0
# 2015-11-01                 704.0                        402.0         1562.0
# 2015-12-01                 747.0                        427.0         1514.0
# 2016-01-01                 710.0                        444.0         1502.0
# 2016-02-01                 677.0                        391.0         1621.0
# 2016-03-01                 749.0                        426.0         1691.0
# 2016-04-01                 767.0                        440.0         1628.0
# 2016-05-01                 833.0                        466.0         1807.0
# 2016-06-01                 781.0                        409.0         1652.0
# 2016-07-01                 742.0                        356.0         1554.0
# 2016-08-01                 745.0                        373.0         1639.0
# 2016-09-01                 700.0                        355.0         1606.0
# 2016-10-01                 796.0                        398.0         1549.0
# 2016-11-01                 762.0                        410.0         1566.0
# 2016-12-01                 724.0                        394.0         1383.0
# 2017-01-01                 760.0                        414.0         1462.0
# 2017-02-01                 720.0                        388.0         1403.0
# 2017-03-01                 750.0                        364.0         1384.0
# 2017-04-01                 804.0                        399.0         1452.0
# 2017-05-01                 858.0                        404.0         1504.0
# 2017-06-01                 909.0                        430.0         1517.0
# 2017-07-01                 892.0                        419.0         1511.0
# 2017-08-01                1048.0                        419.0         1538.0
# 2017-09-01                 942.0                        409.0         1420.0
# 2017-10-01                 940.0                        406.0         1545.0
# 2017-11-01                 871.0                        394.0         1347.0
# 2017-12-01                 966.0                        474.0         1340.0
# 2018-01-01                 885.0                        392.0         1479.0
# 2018-02-01                 721.0                        370.0         1301.0
# 2018-03-01                 877.0                        404.0         1447.0
# 2018-04-01                 912.0                        417.0         1390.0
# 2018-05-01                 966.0                        395.0         1544.0
# 2018-06-01                 926.0                        390.0         1367.0
# 2018-07-01                 985.0                        370.0         1550.0
# 2018-08-01                 931.0                        367.0         1651.0
# 2018-09-01                 862.0                        382.0         1464.0
# 2018-10-01                 900.0                        372.0         1405.0
# 2018-11-01                 848.0                        386.0         1221.0
# 2018-12-01                 900.0                        424.0         1336.0
#
#             Value  PRCP  TAVG
# case_date
# 2014-01-01    9.2  3.02  14.2
# 2014-02-01    9.2  2.72  16.7
# 2014-03-01    8.5  1.35  29.1
# 2014-04-01    7.6  2.89  46.3
# 2014-05-01    7.6  7.09  58.3
# 2014-06-01    7.8  5.88  67.1
# 2014-07-01    7.7  4.27  69.2
# 2014-08-01    7.4  4.80  71.5
# 2014-09-01    6.8  2.87  63.0
# 2014-10-01    6.7  5.14  51.5
# 2014-11-01    6.4  1.57  34.0
# 2014-12-01    6.1  0.86  33.0
# 2015-01-01    7.2  1.45  21.9
# 2015-02-01    6.9  1.70  15.7
# 2015-03-01    6.4  1.08  34.2
# 2015-04-01    6.3  3.20  48.2
# 2015-05-01    6.3  4.22  60.2
# 2015-06-01    6.7  5.21  65.4
# 2015-07-01    6.5  3.41  70.7
# 2015-08-01    6.1  4.97  71.6
# 2015-09-01    5.6  4.74  68.9
# 2015-10-01    5.8  1.66  54.1
# 2015-11-01    5.9  4.72  44.7
# 2015-12-01    6.0  5.40  39.7
# 2016-01-01    6.9  0.72  24.1
# 2016-02-01    6.8  1.21  30.4
# 2016-03-01    6.6  2.46  41.9
# 2016-04-01    6.6  2.63  45.8
# 2016-05-01    5.9  5.85  57.7
# 2016-06-01    6.5  3.57  70.2
# 2016-07-01    6.3  5.75  74.9
# 2016-08-01    6.1  4.27  75.4
# 2016-09-01    6.0  2.46  69.3
# 2016-10-01    5.9  3.84  56.6
# 2016-11-01    5.4  1.82  47.1
# 2016-12-01    5.3  1.61  26.7
# 2017-01-01    5.8  1.31  28.4
# 2017-02-01    5.4  0.69  36.5
# 2017-03-01    4.8  4.56  37.2
# 2017-04-01    4.9  4.93  51.0
# 2017-05-01    4.8  5.37  55.8
# 2017-06-01    5.6  7.18  70.2
# 2017-07-01    5.5  7.93  72.6
# 2017-08-01    5.6  1.66  69.9
# 2017-09-01    5.0  0.75  67.5
# 2017-10-01    4.9  9.39  56.6
# 2017-11-01    4.7  1.95  38.5
# 2017-12-01    4.6  0.58  26.9
# 2018-01-01    5.3  1.29  23.4
# 2018-02-01    5.0  4.92  28.0
# 2018-03-01    4.3  1.39  35.2
# 2018-04-01    3.8  2.83  38.7
# 2018-05-01    3.6  8.78  62.3
# 2018-06-01    4.7  9.75  67.7
# 2018-07-01    4.5  2.76  74.3
# 2018-08-01    4.2  5.41  74.5
# 2018-09-01    3.8  3.67  67.7
# 2018-10-01    4.0  4.57  51.5
# 2018-11-01    3.5  3.47  34.7
# 2018-12-01    3.9  2.27  32.4

# %%
from statsmodels.tsa.stattools import grangercausalitytests

# %%
grangercausalitytests(data_final[['charges_fm', 'monthly_retail_theft_arrest']], maxlag=1)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=7.7810  , p=0.0072  , df_denom=56, df_num=1
# ssr based chi2 test:   chi2=8.1978  , p=0.0042  , df=1
# likelihood ratio test: chi2=7.6761  , p=0.0056  , df=1
# parameter F test:         F=7.7810  , p=0.0072  , df_denom=56, df_num=1
# {1: ({'ssr_ftest': (7.780952340564961, 0.007202709893835798, 56.0, 1),
#    'ssr_chi2test': (8.197789073095228, 0.004194146839430371, 1),
#    'lrtest': (7.676071240665237, 0.005595786405465145, 1),
#    'params_ftest': (7.78095234056496, 0.007202709893835798, 56.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x2009c711df0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x2009c711040>,
#    array([[0., 1., 0.]])])}

# %%
data_final[['charges_fm','monthly_retail_theft_arrest',  'Value',
       'PRCP', 'TAVG']].plot()
# Out:
# <AxesSubplot:xlabel='case_date'>

# %%
pre_period = ['2014-01-01', '2016-11-01']
post_period = ['2016-12-01', '2018-12-01']

figsize = (20, 6)
cilly = CausalImpact(data_final[['charges_m','monthly_retail_theft_arrest']], pre_period, post_period, model_args={'prior_level_sd':0.1, 'fit_method': 'hmc'})
# Out:
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# C:\Users\brand\anaconda3\lib\site-packages\tensorflow_probability\python\mcmc\sample.py:339: UserWarning: Tracing all kernel results by default is deprecated. Set the `trace_fn` argument to None (the future default value) or an explicit callback that traces the values you are interested in.
#   warnings.warn('Tracing all kernel results by default is deprecated. Set '
# WARNING:tensorflow:5 out of the last 5 calls to <function fit_with_hmc.<locals>.run_hmc at 0x000002011813C4C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
data_final.head()
# Out:
#             charges_f  charges_m                                 ucr  \
# case_date
# 2014-01-01      306.0      485.0  {'charge_slug': '54-retail-theft'}
# 2014-02-01      206.0      385.0  {'charge_slug': '54-retail-theft'}
# 2014-03-01      269.0      423.0  {'charge_slug': '54-retail-theft'}
# 2014-04-01      290.0      481.0  {'charge_slug': '54-retail-theft'}
# 2014-05-01      274.0      503.0  {'charge_slug': '54-retail-theft'}
#
#             offense_type  charges_fm  monthly_incidents  monthly_retail_theft  \
# case_date
# 2014-01-01  retail theft       791.0            20056.0                 567.0
# 2014-02-01  retail theft       591.0            18034.0                 525.0
# 2014-03-01  retail theft       692.0            22191.0                 629.0
# 2014-04-01  retail theft       771.0            22929.0                 611.0
# 2014-05-01  retail theft       777.0            24868.0                 704.0
#
#             monthly_retail_theft_arrest  total_charges  Value  PRCP  TAVG
# case_date
# 2014-01-01                        373.0            NaN    9.2  3.02  14.2
# 2014-02-01                        354.0            NaN    9.2  2.72  16.7
# 2014-03-01                        416.0            NaN    8.5  1.35  29.1
# 2014-04-01                        416.0            NaN    7.6  2.89  46.3
# 2014-05-01                        462.0         1940.0    7.6  7.09  58.3

# %%
cilly.plot(figsize=(15, 12))

# %% [markdown]
# ## Review Summary Findings

# %%
print(cilly.summary())
# Out:
# Posterior Inference {Causal Impact}
#                           Average            Cumulative
# Actual                    638.64             15966.0
# Prediction (s.d.)         525.72 (26.11)     13143.0 (652.74)
# 95% CI                    [474.2, 576.55]    [11855.0, 14413.68]
#
# Absolute effect (s.d.)    112.92 (26.11)     2823.0 (652.74)
# 95% CI                    [62.09, 164.44]    [1552.32, 4111.0]
#
# Relative effect (s.d.)    21.48% (4.97%)     21.48% (4.97%)
# 95% CI                    [11.81%, 31.28%]   [11.81%, 31.28%]
#
# Posterior tail-area probability p: 0.0
# Posterior prob. of a causal effect: 100.0%
#
# For more details run the command: print(impact.summary('report'))

# %%
 print(cilly.summary('report'))
# Out:
# Analysis report {CausalImpact}
#
#
# During the post-intervention period, the response variable had
# an average value of approx. 74.4. By contrast, in the absence of an
# intervention, we would have expected an average response of 236.22.
# The 95% interval of this counterfactual prediction is [211.75, 258.23].
# Subtracting this prediction from the observed response yields
# an estimate of the causal effect the intervention had on the
# response variable. This effect is -161.82 with a 95% interval of
# [-183.83, -137.35]. For a discussion of the significance of this effect,
# see below.
#
#
# Summing up the individual data points during the post-intervention
# period (which can only sometimes be meaningfully interpreted), the
# response variable had an overall value of 1860.0.
# By contrast, had the intervention not taken place, we would have expected
# a sum of 5905.52. The 95% interval of this prediction is [5293.64, 6455.78].
#
#
# The above results are given in terms of absolute numbers. In relative
# terms, the response variable showed a decrease of -68.5%. The 95%
# interval of this percentage is [-77.82%, -58.14%].
#
#
# This means that the negative effect observed during the intervention
# period is statistically significant.
# If the experimenter had expected a positive effect, it is recommended
# to double-check whether anomalies in the control variables may have
# caused an overly optimistic expectation of what should have happened
# in the response variable in the absence of the intervention.
#
#
# The probability of obtaining this effect by chance is very small
# (Bayesian one-sided tail-area probability p = 0.0).
# This means the causal effect can be considered statistically
# significant.

# %%
print(ci.summary())
# Out:
# Posterior Inference {Causal Impact}
#                           Average            Cumulative
# Actual                    79.23              2060.0
# Prediction (s.d.)         236.54 (11.33)     6150.0 (294.65)
# 95% CI                    [215.0, 259.42]    [5589.99, 6745.0]
#
# Absolute effect (s.d.)    -157.31 (11.33)    -4090.0 (294.65)
# 95% CI                    [-180.19, -135.77] [-4685.0, -3529.99]
#
# Relative effect (s.d.)    -66.5% (4.79%)     -66.5% (4.79%)
# 95% CI                    [-76.18%, -57.4%]  [-76.18%, -57.4%]
#
# Posterior tail-area probability p: 0.0
# Posterior prob. of a causal effect: 100.0%
#
# For more details run the command: print(impact.summary('report'))

# %% [markdown]
# ### Review Model Output

# %%
ci.inferences.sample(5)
# Out:
#             complete_preds_means  complete_preds_lower  complete_preds_upper  \
# 2016-04-01            251.158051            212.532546            293.095853
# 2018-10-01            229.477676            167.889455            284.967052
# 2015-07-01            270.905457            229.026499            315.268372
# 2018-04-01            229.477676            174.651141            285.341489
# 2014-01-01            306.000000            104.527626            493.048445
#
#             post_preds_means  post_preds_lower  post_preds_upper  post_cum_y  \
# 2016-04-01               NaN               NaN               NaN         NaN
# 2018-10-01        229.477676        167.889455        284.967052      1931.0
# 2015-07-01               NaN               NaN               NaN         NaN
# 2018-04-01        229.477676        174.651141        285.341489      1510.0
# 2014-01-01               NaN               NaN               NaN         NaN
#
#             post_cum_preds_means  post_cum_preds_lower  post_cum_preds_upper  \
# 2016-04-01                   NaN                   NaN                   NaN
# 2018-10-01           5670.649414           5133.932104           6180.446704
# 2015-07-01                   NaN                   NaN                   NaN
# 2018-04-01           4252.987305           3869.840411           4622.325208
# 2014-01-01                   NaN                   NaN                   NaN
#
#             point_effects_means  point_effects_lower  point_effects_upper  \
# 2016-04-01           -24.158051           -66.095853            14.467454
# 2018-10-01          -153.477676          -208.967052           -91.889455
# 2015-07-01           -12.905457           -57.268372            28.973501
# 2018-04-01          -139.477676          -195.341489           -84.651141
# 2014-01-01             0.000000          -187.048445           201.472374
#
#             post_cum_effects_means  post_cum_effects_lower  \
# 2016-04-01                     NaN                     NaN
# 2018-10-01            -3739.650146            -4249.446216
# 2015-07-01                     NaN                     NaN
# 2018-04-01            -2742.987549            -3112.325439
# 2014-01-01                     NaN                     NaN
#
#             post_cum_effects_upper
# 2016-04-01                     NaN
# 2018-10-01            -3202.932098
# 2015-07-01                     NaN
# 2018-04-01            -2359.840894
# 2014-01-01                     NaN

# %%
print(ci.summary('report'))
# Out:
# Analysis report {CausalImpact}
#
#
# During the post-intervention period, the response variable had
# an average value of approx. 79.23. By contrast, in the absence of an
# intervention, we would have expected an average response of 236.54.
# The 95% interval of this counterfactual prediction is [215.0, 259.42].
# Subtracting this prediction from the observed response yields
# an estimate of the causal effect the intervention had on the
# response variable. This effect is -157.31 with a 95% interval of
# [-180.19, -135.77]. For a discussion of the significance of this effect,
# see below.
#
#
# Summing up the individual data points during the post-intervention
# period (which can only sometimes be meaningfully interpreted), the
# response variable had an overall value of 2060.0.
# By contrast, had the intervention not taken place, we would have expected
# a sum of 6150.0. The 95% interval of this prediction is [5589.99, 6745.0].
#
#
# The above results are given in terms of absolute numbers. In relative
# terms, the response variable showed a decrease of -66.5%. The 95%
# interval of this percentage is [-76.18%, -57.4%].
#
#
# This means that the negative effect observed during the intervention
# period is statistically significant.
# If the experimenter had expected a positive effect, it is recommended
# to double-check whether anomalies in the control variables may have
# caused an overly optimistic expectation of what should have happened
# in the response variable in the absence of the intervention.
#
#
# The probability of obtaining this effect by chance is very small
# (Bayesian one-sided tail-area probability p = 0.0).
# This means the causal effect can be considered statistically
# significant.

# %%
pre_period = ['2014-01-01', '2016-11-01']
post_period = ['2016-12-01', '2018-12-01']

figsize = (20, 6)
overall = CausalImpact(data_final[['total_charges','Value',
       'PRCP','TAVG']], pre_period, post_period)
# Out:
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.

# %%
print(overall.summary())
# Out:
# Posterior Inference {Causal Impact}
#                           Average            Cumulative
# Actual                    1438.44            35961.0
# Prediction (s.d.)         1539.29 (143.35)   38482.3 (3583.85)
# 95% CI                    [1134.39, 1696.33] [28359.86, 42408.28]
#
# Absolute effect (s.d.)    -100.85 (143.35)   -2521.3 (3583.85)
# 95% CI                    [-257.89, 304.05]  [-6447.28, 7601.14]
#
# Relative effect (s.d.)    -6.55% (9.31%)     -6.55% (9.31%)
# 95% CI                    [-16.75%, 19.75%]  [-16.75%, 19.75%]
#
# Posterior tail-area probability p: 0.17
# Posterior prob. of a causal effect: 82.52%
#
# For more details run the command: print(impact.summary('report'))

# %%
overall.plot(figsize=(15, 12))
